# %%
import pandas as pd
import numpy as np
import os
from sklearn.cluster import AgglomerativeClustering
from igraph import Graph, plot
import matplotlib.pyplot as plt
import skbio
import subprocess
import utils
import manta
from scipy.cluster.hierarchy import dendrogram
import itertools
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2, venn2_circles
from collections import Counter
from venn import venn

# %load_ext autoreload
# %aimport utils
# %aimport manta
# %autoreload 1

# %% [markdown]
# # Read data and preprocess

# %%
TAX_LEVEL = 4
OUTDIR = 'data/18S_l5_ur'
SEASON = 'Upwelling Relaxation'

# %%
# Read data
df_raw = pd.read_excel('data/18S_AV_OTU_table_wTaxa.xlsx')
meta = pd.read_excel('data/18S_AV_March2019_Metadata.xlsx')
meta
# Out:
#             Sample_Names    Sample_NamesR AV_Numbers      Month  Year  \
# 0               AV12-18S    AV12_Jan_2018   AV180126    January  2018
# 1               AV13-18S    AV13_Feb_2018   AV180202   February  2018
# 2               AV14-18S    AV14_Feb_2018   AV180209   February  2018
# 3             AV17-2-18S  AV17_Feb_2018_2   AV180216   February  2018
# 4               AV18-18S    AV18_Feb_2018   AV180223   February  2018
# 5               AV19-18S    AV19_Mar_2018   AV180302      March  2018
# 6               AV22-18S    AV22_Mar_2018   AV180309      March  2018
# 7   AP-AV23-AV180316-18S    AV23_Mar_2018   AV180316      March  2018
# 8               AV26-18S    AV26_Apr_2018   AV180413      April  2018
# 9   AP-AV29-AV180420-18S    AV29_Apr_2018   AV180420      April  2018
# 10              AV32-18S    AV32_Apr_2018   AV180427      April  2018
# 11              AV35-18S    AV35_May_2018   AV180504        May  2018
# 12              AV38-18S    AV38_May_2018   AV180511        May  2018
# 13  AP-AV41-AV180518-18S    AV41_May_2018   AV180518        May  2018
# 14              AV44-18S    AV44_May_2018   AV180525        May  2018
# 15              AV47-18S    AV47_Jun_2018   AV180601       June  2018
# 16              AV50-18S    AV60_Jul_2018   AV180720       July  2018
# 17              AV53-18S    AV53_Jul_2018   AV180727       July  2018
# 18              AV56-18S    AV56_Aug_2018   AV180803     August  2018
# 19              AV59-18S    AV59_Aug_2018   AV180810     August  2018
# 20              AV66-18S    AV66_Aug_2018   AV180824     August  2018
# 21              AV69-18S    AV69_Sep_2018   AV180928  September  2018
# 22              AV72-18S    AV72_Oct_2018   AV181005    October  2018
# 23              AV75-18S    AV75_Oct_2018   AV181012    October  2018
# 24              AV78-18S    AV78_Oct_2018   AV181026    October  2018
# 25              AV81-18S    AV81_Nov_2018   AV181109   November  2018
# 26              AV84-18S    AV84_Nov_2018   AV181116   November  2018
# 27              AV90-18S    AV90_Dec_2018   AV181207   December  2018
#
#                   Season  Temp_C  Salinity  Chlorophyll_ugL
# 0          Winter Storms   12.60      33.4              NaN
# 1          Winter Storms   13.80      33.4              NaN
# 2          Winter Storms   14.30      33.4           18.916
# 3          Winter Storms   13.10      33.4            1.624
# 4          Winter Storms   12.00      33.4            1.818
# 5       March Transition   11.50      33.3            1.113
# 6       March Transition   12.72      33.4            7.338
# 7       March Transition   13.00      33.4            3.602
# 8         Peak Upwelling   10.60      33.7            0.652
# 9         Peak Upwelling   11.30      33.3            8.615
# 10        Peak Upwelling   12.80      33.7            1.394
# 11        Peak Upwelling   12.30      33.7            2.615
# 12        Peak Upwelling   12.40      33.7            2.150
# 13        Peak Upwelling   13.80      33.8            2.012
# 14        Peak Upwelling   13.10      33.8            1.543
# 15       June Transition   12.40      33.7            3.182
# 16  Upwelling Relaxation   16.80      33.6            3.150
# 17  Upwelling Relaxation   15.60      33.6            6.459
# 18  Upwelling Relaxation   15.60      33.7            4.106
# 19  Upwelling Relaxation   15.20      33.6           13.516
# 20  Upwelling Relaxation   16.90      33.6            4.831
# 21  Upwelling Relaxation   15.80      33.4          155.815
# 22     Winter Transition   16.60      33.3           40.993
# 23     Winter Transition   15.60      33.3           76.025
# 24     Winter Transition   15.40      33.5            4.922
# 25     Winter Transition   14.80      33.5            4.248
# 26     Winter Transition   16.50      33.6            2.077
# 27         Winter Storms   13.70      33.5            1.117

# %%
# Split taxonomy
df_raw['taxonomy'] = df_raw['taxonomy'].str.split('; ')
# Taxonomy depth distribution
tax_depth = df_raw['taxonomy'].apply(len)
tax_depth.value_counts()
# Out:
# 8    8258
# 7    1058
# 6     265
# 4     228
# 5     160
# 3      10
# 2       2
# 1       2
# Name: taxonomy, dtype: int64

# %%
# Filter out OTUs with coarser taxonomy than the desired level and group them at that level
df_raw = df_raw[tax_depth >= TAX_LEVEL]
df_raw['taxonomy'] = df_raw['taxonomy'].apply(lambda x: '; '.join(x[:TAX_LEVEL]))
df = df_raw.groupby('taxonomy').aggregate(np.sum)
df
# Out:
#                                                     AV22-18S  AV17-2-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X          22           7
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0           0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0           0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  1           1
# Eukaryota; Alveolata; Ciliophora; CONThreeP               37          46
# ...                                                      ...         ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         1           0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0           0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0           0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0           0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0           2
#
#                                                     AV13-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           4
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0
# Eukaryota; Alveolata; Ciliophora; CONThreeP                8
# ...                                                      ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         1
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         1
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         4
#
#                                                     AP-AV29-AV180420-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X                      18
# Eukaryota; Alveolata; Ciliophora; CONTH_3                              0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                              0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                              0
# Eukaryota; Alveolata; Ciliophora; CONThreeP                            0
# ...                                                                  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...                     0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...                     0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...                     0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...                     0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...                     0
#
#                                                     AV44-18S  AV53-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X         161         0
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  9         0
# Eukaryota; Alveolata; Ciliophora; CONThreeP               36         2
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...        24         0
#
#                                                     AV32-18S  AV12-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           2        22
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                157         0
# Eukaryota; Alveolata; Ciliophora; CONThreeP              100         8
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         4
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         2
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         2         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         9         0
#
#                                                     AV38-18S  AV90-18S  ...  \
# taxonomy                                                                ...
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X          24       532  ...
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         2  ...
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         3  ...
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         0  ...
# Eukaryota; Alveolata; Ciliophora; CONThreeP              128        82  ...
# ...                                                      ...       ...  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         1       141  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         3         0  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0       223  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         2         2  ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         5        61  ...
#
#                                                     AV14-18S  AV59-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         1
# Eukaryota; Alveolata; Ciliophora; CONThreeP                0         0
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
#
#                                                     AV66-18S  AV50-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           0         1
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         3
# Eukaryota; Alveolata; Ciliophora; CONThreeP                0         6
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
#
#                                                     AV78-18S  AV81-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           1         1
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         1
# Eukaryota; Alveolata; Ciliophora; CONThreeP                0         3
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
#
#                                                     AV75-18S  AV72-18S  \
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X          51         1
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         0
# Eukaryota; Alveolata; Ciliophora; CONThreeP                0         0
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
#
#                                                     AV69-18S  AV56-18S
# taxonomy
# Eukaryota; Alveolata; Apicomplexa; Apicomplexa_X           0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_3                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_6                  0         0
# Eukaryota; Alveolata; Ciliophora; CONTH_8                  0         0
# Eukaryota; Alveolata; Ciliophora; CONThreeP                0         0
# ...                                                      ...       ...
# Eukaryota; Stramenopiles; Stramenopiles_X; Pirs...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Stra...         0         0
#
# [85 rows x 28 columns]

# %%
# Effective number of species
np.exp(skbio.diversity.alpha_diversity('shannon', df.transpose())).mean()
# Out:
# 4.759163478066598

# %% [markdown]
# # Filter vertices

# %%
samples = meta['Sample_Names'][meta['Season'] == SEASON]
df = df[samples]

# %%
df_relative = df / df.sum()
df = df[((df > 0).sum(axis=1) > 2) | (df_relative > .01).any(axis=1)]

# %%
df /= df.sum()

# %%
df.to_csv('18s_ur_1percent_3samples.csv')

# %%
df
# Out:
#                                                     AV50-18S  AV53-18S  \
# taxonomy
# Eukaryota; Alveolata; Ciliophora; Nassophorea              1         4
# Eukaryota; Alveolata; Ciliophora; Phyllopharyngea          3         5
# Eukaryota; Alveolata; Ciliophora; Spirotrichea            48        85
# Eukaryota; Alveolata; Dinoflagellata; Dinophyceae      13223    135786
# Eukaryota; Alveolata; Dinoflagellata; Syndiniales        115       994
# Eukaryota; Archaeplastida; Chlorophyta; Chlorop...         3        44
# Eukaryota; Archaeplastida; Chlorophyta; Mamiell...       292        74
# Eukaryota; Archaeplastida; Chlorophyta; Prasino...         1         5
# Eukaryota; Archaeplastida; Chlorophyta; Pyramim...         5        90
# Eukaryota; Archaeplastida; Chlorophyta; Ulvophy...         5        11
# Eukaryota; Hacrobia; Centroheliozoa; Centroheli...         2         1
# Eukaryota; Hacrobia; Cryptophyta; Cryptophyceae           10        18
# Eukaryota; Hacrobia; Katablepharidophyta; Katab...         1        20
# Eukaryota; Hacrobia; Picozoa; Picozoa_X                    6        16
# Eukaryota; Rhizaria; Cercozoa; Filosa-Imbricatea           1        10
# Eukaryota; Rhizaria; Cercozoa; Filosa-Thecofilosea         7       285
# Eukaryota; Rhizaria; Radiolaria; Acantharea                9        15
# Eukaryota; Stramenopiles; Ochrophyta; Bacillari...       220       288
# Eukaryota; Stramenopiles; Ochrophyta; Chrysophy...         5        12
# Eukaryota; Stramenopiles; Ochrophyta; Dictyocho...        14        14
# Eukaryota; Stramenopiles; Ochrophyta; Raphidoph...        19        65
# Eukaryota; Stramenopiles; Stramenopiles_X; Laby...         5         5
# Eukaryota; Stramenopiles; Stramenopiles_X; MAST            1        16
#
#                                                     AV56-18S  AV59-18S  \
# taxonomy
# Eukaryota; Alveolata; Ciliophora; Nassophorea              0         0
# Eukaryota; Alveolata; Ciliophora; Phyllopharyngea          0         3
# Eukaryota; Alveolata; Ciliophora; Spirotrichea             0        58
# Eukaryota; Alveolata; Dinoflagellata; Dinophyceae      18691     11176
# Eukaryota; Alveolata; Dinoflagellata; Syndiniales          3       159
# Eukaryota; Archaeplastida; Chlorophyta; Chlorop...         0         1
# Eukaryota; Archaeplastida; Chlorophyta; Mamiell...         1        29
# Eukaryota; Archaeplastida; Chlorophyta; Prasino...         0         1
# Eukaryota; Archaeplastida; Chlorophyta; Pyramim...         0        17
# Eukaryota; Archaeplastida; Chlorophyta; Ulvophy...         0         7
# Eukaryota; Hacrobia; Centroheliozoa; Centroheli...         0         1
# Eukaryota; Hacrobia; Cryptophyta; Cryptophyceae            0         4
# Eukaryota; Hacrobia; Katablepharidophyta; Katab...         0         4
# Eukaryota; Hacrobia; Picozoa; Picozoa_X                    0         1
# Eukaryota; Rhizaria; Cercozoa; Filosa-Imbricatea           0         1
# Eukaryota; Rhizaria; Cercozoa; Filosa-Thecofilosea         0         7
# Eukaryota; Rhizaria; Radiolaria; Acantharea                0         3
# Eukaryota; Stramenopiles; Ochrophyta; Bacillari...         0        31
# Eukaryota; Stramenopiles; Ochrophyta; Chrysophy...         0         1
# Eukaryota; Stramenopiles; Ochrophyta; Dictyocho...         0         6
# Eukaryota; Stramenopiles; Ochrophyta; Raphidoph...         0        51
# Eukaryota; Stramenopiles; Stramenopiles_X; Laby...         0         1
# Eukaryota; Stramenopiles; Stramenopiles_X; MAST            0         2
#
#                                                     AV66-18S  AV69-18S
# taxonomy
# Eukaryota; Alveolata; Ciliophora; Nassophorea              2         0
# Eukaryota; Alveolata; Ciliophora; Phyllopharyngea          1         0
# Eukaryota; Alveolata; Ciliophora; Spirotrichea             3         1
# Eukaryota; Alveolata; Dinoflagellata; Dinophyceae      12770     23810
# Eukaryota; Alveolata; Dinoflagellata; Syndiniales         20         4
# Eukaryota; Archaeplastida; Chlorophyta; Chlorop...         1         1
# Eukaryota; Archaeplastida; Chlorophyta; Mamiell...         0         0
# Eukaryota; Archaeplastida; Chlorophyta; Prasino...         0         0
# Eukaryota; Archaeplastida; Chlorophyta; Pyramim...         2         1
# Eukaryota; Archaeplastida; Chlorophyta; Ulvophy...         0         0
# Eukaryota; Hacrobia; Centroheliozoa; Centroheli...         0         0
# Eukaryota; Hacrobia; Cryptophyta; Cryptophyceae            0         0
# Eukaryota; Hacrobia; Katablepharidophyta; Katab...         0         0
# Eukaryota; Hacrobia; Picozoa; Picozoa_X                    0         0
# Eukaryota; Rhizaria; Cercozoa; Filosa-Imbricatea           0         0
# Eukaryota; Rhizaria; Cercozoa; Filosa-Thecofilosea         0         0
# Eukaryota; Rhizaria; Radiolaria; Acantharea                0         0
# Eukaryota; Stramenopiles; Ochrophyta; Bacillari...         6         0
# Eukaryota; Stramenopiles; Ochrophyta; Chrysophy...         0         0
# Eukaryota; Stramenopiles; Ochrophyta; Dictyocho...         0         1
# Eukaryota; Stramenopiles; Ochrophyta; Raphidoph...         1         0
# Eukaryota; Stramenopiles; Stramenopiles_X; Laby...         1         0
# Eukaryota; Stramenopiles; Stramenopiles_X; MAST            0         0

# %% [markdown]
# # Build graph

# %%
df_cor, df_pval = utils.run_sparcc(df, OUTDIR, force=True)

# %%
flatten_cor = utils.flatten_square_df(df_cor, k=1)
plt.hist(flatten_cor)
# Out:
# (array([ 6., 19., 24., 47., 49., 45., 27., 20.,  6., 10.]),
#  array([-0.6836 , -0.53824, -0.39288, -0.24752, -0.10216,  0.0432 ,
#          0.18856,  0.33392,  0.47928,  0.62464,  0.77   ]),
#  <a list of 10 Patch objects>)

# %%
g = utils.build_graph(df_cor, df_pval)
utils.graph_stats(g)
# Out:
# # edges: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bde4fecd0db6> in <module>
#       1 g = utils.build_graph(df_cor, df_pval)
# ----> 2 utils.graph_stats(g)
#
# ~/thesis/utils.py in graph_stats(g)
#      82 def graph_stats(g):
#      83     print(f'# edges: {len(g.es)}')
# ---> 84     print(f'# positive edges: {(np.array(g.es["weight"]) > 0).sum()}')
#      85     print(f'# negative edges: {(np.array(g.es["weight"]) < 0).sum()}')
#      86     print(f'max degree: {np.max(g.degree())}')
#
# KeyError: 'Attribute does not exist'

# %%
len(g.vs)
# Out:
# 34

# %% [markdown]
# # Run manta

# %%
g = g.components().subgraph(0)
g.write_gml(os.path.join(OUTDIR, 'graph.gml'))

# %%
subprocess.run(['manta',
                '-i', os.path.join(OUTDIR, 'graph.gml'),
                '-o', os.path.join(OUTDIR, 'graph_manta'),
                '-min', '2',
                '-max', '4',
                '-f', 'gml',
                '-b',
                '-v',
               ],
               check=True)
g_manta = Graph.Read_GML(os.path.join(OUTDIR, 'graph_manta.gml'))

# %%
utils.graph_stats(g_manta)
# Out:
# # edges: 108
# # positive edges: 58
# # negative edges: 50
# max degree: 21
# min degree: 1
# median degree: 6.0
# transitivity: 0.4211099020674646

# %%
#g_manta.vs.select(assignment='weak').delete()

# %%
Counter(g_manta.vs['cluster'])
# Out:
# Counter({1.0: 18, 0.0: 14})

# %%
#g_manta.vs.select(cluster=0.0)['label']

# %%
# sets = {
#     'pu_0': set(g_pu_manta.vs.select(cluster=0.0)['label']),
#     'pu_1': set(g_pu_manta.vs.select(cluster=1.0)['label']),
#     'ur_0': set(g_ur_manta.vs.select(cluster=0.0)['label']),
#     'ur_1': set(g_ur_manta.vs.select(cluster=1.0)['label'])
# }
# fig, ax = plt.subplots(1, figsize=(16,12))
# venn(sets, ax=ax)
# #plt.legend(labels[:-2], ncol=6)

# %%
g_manta.es['abs_weight'] = list(map(abs, g_manta.es['weight']))

# %%
def assign_color(e):
    if e.source_vertex['cluster'] == e.target_vertex['cluster']:
        return 'green' if e['weight'] >= 0 else 'red'
    else:
        return 'blue' if e['weight'] >= 0 else 'orange'
g_manta.es['color'] = list(map(assign_color, g_manta.es))

# %%
def clean_label(label):
    return '; '.join(map(lambda x: x.strip('_'), label.split('; ')[1:]))
g_manta.vs['label'] = list(map(clean_label, g_manta.vs['label']))

# %%
g_manta.write_gml(os.path.join(OUTDIR, 'graph_cytoscape.gml'))

# %%
g_pu.es.find(_between=((80,), (7,)))['weight']

# %%
for clique in g_pu.cliques(3):
    all_negative = True
    for v1,v2 in itertools.combinations(clique, 2):
        if g_pu.es.find(_between=((v1,), (v2,)))['weight'] > 0:
            all_negative = False
    if all_negative:
        print(clique)

# %%
g_pu.es.select(weight_lt=0).delete()
g_ur.es.select(weight_lt=0).delete()
g_pu.vs.select(_degree=0).delete()
g_ur.vs.select(_degree=0).delete()

# %%
g_ur.clique_number()

# %%
# p, labels = plot_graph(g_pu)
# p

# %%
# g_pu.vs['label'] = labels

# %%
# p, labels = plot_graph(g_ur)
# p

# %%
# g_ur.vs['label'] = labels

# %%
# hierarchical clustering
adjacency_matrix = np.array(g_pu.get_adjacency(attribute='weight').data)
adjacency_matrix[adjacency_matrix < 0] = 0
# adjacency_matrix = (adjacency_matrix + 1) / 2
adjacency_matrix = 1 - adjacency_matrix
clusteror = AgglomerativeClustering(n_clusters=None, affinity='precomputed', linkage='complete', distance_threshold=.5)
a = clusteror.fit_predict(adjacency_matrix)

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
plt.title('Hierarchical Clustering Dendrogram')
# plot the top three levels of the dendrogram
plot_dendrogram(clusteror, truncate_mode='level', p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
# for e in g_pu.es.select(weight_ge=.7):
#     print(e.source_vertex['label'], e.target_vertex['label'], e['weight'])

# %%
# plot(g_pu.degree_distribution())

# %%
# for v in g_pu.vs.select(_degree_ge=40):
#     print(v['label'])

# %%
# ccs = g_pu.components()
# ccs = [ccs.subgraph(i) for i, vs in enumerate(ccs) if len(vs) > 1]
# print(f'Number of components: {len(ccs)}')

# %%
# for cc in ccs:
#     print(len(cc.vs))

# %%
clustering = g_pu.community_fastgreedy().as_clustering()
#small = [clustering.subgraph(i) for i, vs in enumerate(clustering) if len(vs) < 10][0]
#ccs[0].vs['label'] = None
#plot(clustering)

# %%
for i in range(len(clustering)):
    module = clustering.subgraph(i)
    for v in module.vs:
        print(v['label'])
    print()

# %%
clustering = g_ur.community_fastgreedy().as_clustering()
for i in range(len(clustering)):
    module = clustering.subgraph(i)
    for v in module.vs:
        print(v['label'])
    print()
